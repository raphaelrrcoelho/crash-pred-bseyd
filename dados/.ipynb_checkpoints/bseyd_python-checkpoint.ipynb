# %%
import pandas as pd
import numpy as np
import math
from scipy.stats import norm
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
dados = pd.read_excel('./BSEYD_EUA_dados.xlsx', engine='openpyxl', index_col='Dates')

# %%
dados
# Out:
#             spx_index  spx_earnings  gt10_govt
# Dates
# 1962-01-05      69.66        4.7059      4.022
# 1962-01-08      69.12        4.7059      4.032
# 1962-01-09      69.15        4.7059      4.052
# 1962-01-10      68.96        4.7059      4.072
# 1962-01-11      69.37        4.7059      4.082
# ...               ...           ...        ...
# 2021-04-13    4141.59        3.0882      1.616
# 2021-04-14    4124.66        3.1008      1.633
# 2021-04-15    4170.42        3.0668      1.578
# 2021-04-16    4185.47        3.0558      1.582
# 2021-04-19    4162.77        3.0725      1.600
#
# [15467 rows x 3 columns]

# %%
dados['spx_bseyd'] = dados['gt10_govt'] - dados['spx_earnings']

# %%
dados
# Out:
#             spx_index  spx_earnings  gt10_govt  spx_bseyd
# Dates
# 1962-01-05      69.66        4.7059      4.022    -0.6839
# 1962-01-08      69.12        4.7059      4.032    -0.6739
# 1962-01-09      69.15        4.7059      4.052    -0.6539
# 1962-01-10      68.96        4.7059      4.072    -0.6339
# 1962-01-11      69.37        4.7059      4.082    -0.6239
# ...               ...           ...        ...        ...
# 2021-04-13    4141.59        3.0882      1.616    -1.4722
# 2021-04-14    4124.66        3.1008      1.633    -1.4678
# 2021-04-15    4170.42        3.0668      1.578    -1.4888
# 2021-04-16    4185.47        3.0558      1.582    -1.4738
# 2021-04-19    4162.77        3.0725      1.600    -1.4725
#
# [15467 rows x 4 columns]

# %%
dados['mean_movel'] = dados['spx_bseyd'].rolling(252).mean()

# %%
dados['sd_movel'] = dados['spx_bseyd'].rolling(252).std()

# %%
dados['z_score'] = (dados['spx_bseyd'] - dados['mean_movel'])/dados['sd_movel']

# %%
dados['cl'] = dados['spx_bseyd'] + dados['z_score']*np.sqrt((dados['sd_movel']**2)/252)


"""
mean_movel - (norm_movel*(sqrt(sd_movel**2/252)))

"""
#dados['cl'] = dados['spx_bseyd'] + dados['z_score']*np.sqrt((dados['sd_movel']**2)/252)

dados
# Out:
#             spx_index  spx_earnings  gt10_govt  spx_bseyd  mean_movel  \
# Dates
# 1962-01-05      69.66        4.7059      4.022    -0.6839         NaN
# 1962-01-08      69.12        4.7059      4.032    -0.6739         NaN
# 1962-01-09      69.15        4.7059      4.052    -0.6539         NaN
# 1962-01-10      68.96        4.7059      4.072    -0.6339         NaN
# 1962-01-11      69.37        4.7059      4.082    -0.6239         NaN
# ...               ...           ...        ...        ...         ...
# 2021-04-13    4141.59        3.0882      1.616    -1.4722   -2.881310
# 2021-04-14    4124.66        3.1008      1.633    -1.4678   -2.869733
# 2021-04-15    4170.42        3.0668      1.578    -1.4888   -2.857946
# 2021-04-16    4185.47        3.0558      1.582    -1.4738   -2.846676
# 2021-04-19    4162.77        3.0725      1.600    -1.4725   -2.835287
#
#             sd_movel   z_score        cl
# Dates
# 1962-01-05       NaN       NaN       NaN
# 1962-01-08       NaN       NaN       NaN
# 1962-01-09       NaN       NaN       NaN
# 1962-01-10       NaN       NaN       NaN
# 1962-01-11       NaN       NaN       NaN
# ...              ...       ...       ...
# 2021-04-13  0.836239  1.685057 -1.383434
# 2021-04-14  0.835530  1.677896 -1.379487
# 2021-04-15  0.833970  1.641721 -1.402552
# 2021-04-16  0.833406  1.647307 -1.387317
# 2021-04-19  0.832493  1.636995 -1.386652
#
# [15467 rows x 8 columns]

# %%
for index, row in dados.iterrows():
    if row['z_score'] < row['cl']:
        dados.loc[index,'signal_bseyd'] = 1
    else:
        dados.loc[index,'signal_bseyd'] = 0

# %%
dados
# Out:
#             spx_index  spx_earnings  gt10_govt  spx_bseyd  mean_movel  \
# Dates
# 1962-01-05      69.66        4.7059      4.022    -0.6839         NaN
# 1962-01-08      69.12        4.7059      4.032    -0.6739         NaN
# 1962-01-09      69.15        4.7059      4.052    -0.6539         NaN
# 1962-01-10      68.96        4.7059      4.072    -0.6339         NaN
# 1962-01-11      69.37        4.7059      4.082    -0.6239         NaN
# ...               ...           ...        ...        ...         ...
# 2021-04-13    4141.59        3.0882      1.616    -1.4722   -2.881310
# 2021-04-14    4124.66        3.1008      1.633    -1.4678   -2.869733
# 2021-04-15    4170.42        3.0668      1.578    -1.4888   -2.857946
# 2021-04-16    4185.47        3.0558      1.582    -1.4738   -2.846676
# 2021-04-19    4162.77        3.0725      1.600    -1.4725   -2.835287
#
#             sd_movel   z_score        cl  signal_bseyd
# Dates
# 1962-01-05       NaN       NaN       NaN           0.0
# 1962-01-08       NaN       NaN       NaN           0.0
# 1962-01-09       NaN       NaN       NaN           0.0
# 1962-01-10       NaN       NaN       NaN           0.0
# 1962-01-11       NaN       NaN       NaN           0.0
# ...              ...       ...       ...           ...
# 2021-04-13  0.836239  1.685057 -1.383434           0.0
# 2021-04-14  0.835530  1.677896 -1.379487           0.0
# 2021-04-15  0.833970  1.641721 -1.402552           0.0
# 2021-04-16  0.833406  1.647307 -1.387317           0.0
# 2021-04-19  0.832493  1.636995 -1.386652           0.0
#
# [15467 rows x 9 columns]

# %%
"""
BSEYD_usa = 
  BSEYD_usa %>%
  mutate(signal_bseyd_teste22 = spx_bseyd - ci) %>%
  mutate(signal_bseyd_ss = ifelse(signal_bseyd_teste>0, 1,0))
"""
dados['signal_bseyd_teste'] = dados['spx_bseyd'] - dados['cl']

# %%
for index, row in dados.iterrows():
    if row['signal_bseyd_teste'] > 0:
        dados.loc[index,'signal_bseydss'] = 1
    else:
        dados.loc[index,'signal_bseydss'] = 0

# %%
"""
s1_teste = rollsum(BSEYD_usa$signal_bseyd_ss, 31, align='right', fill=NA)
BSEYD_usa = cbind(BSEYD_usa,s1_teste)

"""

dados['s1_teste'] = dados['signal_bseydss'].rolling(30).sum()
dados
# Out:
#             spx_index  spx_earnings  gt10_govt  spx_bseyd  mean_movel  \
# Dates
# 1962-01-05      69.66        4.7059      4.022    -0.6839         NaN
# 1962-01-08      69.12        4.7059      4.032    -0.6739         NaN
# 1962-01-09      69.15        4.7059      4.052    -0.6539         NaN
# 1962-01-10      68.96        4.7059      4.072    -0.6339         NaN
# 1962-01-11      69.37        4.7059      4.082    -0.6239         NaN
# ...               ...           ...        ...        ...         ...
# 2021-04-13    4141.59        3.0882      1.616    -1.4722   -2.881310
# 2021-04-14    4124.66        3.1008      1.633    -1.4678   -2.869733
# 2021-04-15    4170.42        3.0668      1.578    -1.4888   -2.857946
# 2021-04-16    4185.47        3.0558      1.582    -1.4738   -2.846676
# 2021-04-19    4162.77        3.0725      1.600    -1.4725   -2.835287
#
#             sd_movel   z_score        cl  signal_bseyd  signal_bseyd_teste  \
# Dates
# 1962-01-05       NaN       NaN       NaN           0.0                 NaN
# 1962-01-08       NaN       NaN       NaN           0.0                 NaN
# 1962-01-09       NaN       NaN       NaN           0.0                 NaN
# 1962-01-10       NaN       NaN       NaN           0.0                 NaN
# 1962-01-11       NaN       NaN       NaN           0.0                 NaN
# ...              ...       ...       ...           ...                 ...
# 2021-04-13  0.836239  1.685057 -1.383434           0.0           -0.088766
# 2021-04-14  0.835530  1.677896 -1.379487           0.0           -0.088313
# 2021-04-15  0.833970  1.641721 -1.402552           0.0           -0.086248
# 2021-04-16  0.833406  1.647307 -1.387317           0.0           -0.086483
# 2021-04-19  0.832493  1.636995 -1.386652           0.0           -0.085848
#
#             signal_bseydss  s1_teste
# Dates
# 1962-01-05             0.0       NaN
# 1962-01-08             0.0       NaN
# 1962-01-09             0.0       NaN
# 1962-01-10             0.0       NaN
# 1962-01-11             0.0       NaN
# ...                    ...       ...
# 2021-04-13             0.0       0.0
# 2021-04-14             0.0       0.0
# 2021-04-15             0.0       0.0
# 2021-04-16             0.0       0.0
# 2021-04-19             0.0       0.0
#
# [15467 rows x 12 columns]

# %%
"""
 BSEYD_usa =
   BSEYD_usa %>%
   mutate(S = (ifelse((s1_teste==1) & (signal_bseyd_teste==1) ,1, 0)))

"""
for index, row in dados.iterrows():
    if (row['s1_teste']==1) & (row['signal_bseydss'] ==1):
        dados.loc[index,'s'] = 1
    else:
        dados.loc[index,'s'] = 0

# %%
dados = dados.to_excel('dados.xlsx', index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-a8e4f9a695d6> in <module>
# ----> 1 dados = dados.to_excel('dados.xlsx', index=True)
#
# AttributeError: 'NoneType' object has no attribute 'to_excel'

# %%
a=dados['s'].sum()
a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-9aa11f7c2996> in <module>
# ----> 1 a=dados['s'].sum()
#       2 a
#
# TypeError: 'NoneType' object is not subscriptable

# %%
plt.plot(dados['signal_bseyd'])	
plt.show()
